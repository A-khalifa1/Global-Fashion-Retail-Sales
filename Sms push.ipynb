# %%
import pyodbc
import csv
from kafka import KafkaConsumer
import json
import os

# SQL Server connection
def get_customer_info(customer_id):
    conn = pyodbc.connect(
        r"Driver={ODBC Driver 17 for SQL Server};"
        r"Server=DESKTOP-GU1M2GE\SQLEXPRESS;"
        r"Database=Skippy;"
        r"Trusted_Connection=yes;"
    )
    
    query = """
    SELECT [Telephone], [Name] FROM [Skippy].[dbo].[customers] WHERE [Customer ID] = ?
    """
    cursor = conn.cursor()
    cursor.execute(query, customer_id)
    result = cursor.fetchone()
    conn.close()
    
    if result:
        return result[0], result[1]  # Return both Telephone and Name
    return None, None

# Kafka Consumer
consumer = KafkaConsumer(
    'skippy',  # Topic
    bootstrap_servers='localhost:9092',  # Kafka server
    group_id='your_group_id',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# Open the CSV file in append mode
file_exists = os.path.exists('for_push.csv')

# Track processed customer IDs to avoid duplication
processed_customer_ids = set()

with open('for_push.csv', mode='a', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Telephone', 'Message']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write header if the file doesn't already exist
    if not file_exists:
        writer.writeheader()

    for message in consumer:
        data = message.value

        # Check if the customer ID has already been processed
        customer_id = data['Customer ID']
        if customer_id in processed_customer_ids:
            continue  # Skip this record if it's already processed

        # Get customer phone number and name from the database
        customer_phone, customer_name = get_customer_info(customer_id)

        if customer_phone and customer_name:
            # Prepare the personalized message
            thank_you_message = f"Dear {customer_name}, thank you for visiting Skippy, we wish you a wonderful day!"

            # Write to the CSV file
            writer.writerow({'Telephone': customer_phone, 'Message': thank_you_message})
            csv_file.flush()  # Ensure immediate write
            print(f"Saved: {customer_phone} - {thank_you_message}")

            # Mark this customer ID as processed
            processed_customer_ids.add(customer_id)
        else:
            print(f"Phone number or name for Customer ID {customer_id} not found.")
# Out:
# Saved: +33 3 25 13 71 87 - Dear Marie Lombard-Lombard, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (430)394-3653 - Dear Nathaniel James, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 449.236.8295x981 - Dear Frances Schmidt, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (235)924-0017x8762 - Dear Edward Jackson, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15097919542 - Dear Chen Dan Dan, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 13551542442 - Dear Cao Hui, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15903038828 - Dear Song Xue Mei, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15096639567 - Dear Zhang Hao, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15224629446 - Dear Song Ying, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 01229 646753 - Dear Anja Geissler B.Eng., thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +33 4 97 07 97 41 - Dear Denise Gaillard, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 0486821054 - Dear Dominique Boulay, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (351) 962 088 482 - Dear Patricia Mendes, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (351) 918274959 - Dear Lisandro Moura-Ramos, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 6759179747 - Dear Joseph Suarez, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 663-974-9697 - Dear Dr. Norman Frey, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 365-778-5707 - Dear Sydney Lopez, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 313.547.9371x13677 - Dear Sandra Brown, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 338.769.7568 - Dear Catherine Jones, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (954)777-5327x2831 - Dear Dennis Wiley, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 18817405730 - Dear Shen Dan Dan, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15531437553 - Dear Li Xiu Yun, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 14580507939 - Dear Cao Bin, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +49(0) 842538290 - Dear Hans-Wolfgang Hering-Nerger, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +49(0)9227 671247 - Dear Silva Textor, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +34 900929971 - Dear Violeta Ainoa Pulido Peral, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 0235420948 - Dear Adele De Oliveira, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 0479734164 - Dear Marthe Moreno, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 262217956 - Dear Daniela Coelho, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (708)913-1677x994 - Dear Tara Lopez, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: (683)343-2563x92155 - Dear Barbara Flores, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 914-253-9251 - Dear John Martin, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15074977521 - Dear Yue Gui Lan, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 15395483753 - Dear Li Rui, thank you for visiting Skippy, we wish you a wonderful day!
# Saved:
thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +49 (0) 4918 498995 - Dear Eugenie Schonland B.Sc., thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +49(0)9121887976 - Dear Prof. Heidelinde Jantsch, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 02644 302582 - Dear Karl-Werner Klapp, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +33 (0)4 66 15 32 79 - Dear Roland-Jerome Joseph, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 001-416-462-5255x87905 - Dear Jennifer Cole, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 755.204.3989x53670 - Dear Brandon Lopez, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +1-822-930-9333 - Dear Ryan Sullivan, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 001-617-390-9068 - Dear Mrs. Melissa Davis MD, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 001-548-670-1869x22980 - Dear Timothy Johnson, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 13171157116 - Dear Xia Ying, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +34721 47 71 06 - Dear Febe Romeu Figueras, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +34 949 03 98 26 - Dear Diego de Cabo, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 0176499884 - Dear Simone Le Michel, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: +33 (0)4 11 94 30 49 - Dear Charlotte Bertrand, thank you for visiting Skippy, we wish you a wonderful day!
# Saved: 05 82 00 63 11 - Dear Vincent de la Rossi, thank you for visiting Skippy, we wish you a wonderful day!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 50
#      47 if not file_exists:
#      48     writer.writeheader()
# ---> 50 for message in consumer:
#      51     data = message.value
#      53     # Check if the customer ID has already been processed
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:693, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     691 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     692 while not self._closed:
# --> 693     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     694     if records:
#     695         return records
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:736, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     733 if records:
#     734     return records
# --> 736 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     737 # after the long poll, we should check whether the group needs to rebalance
#     738 # prior to returning data so that the group can stabilize faster
#     739 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
